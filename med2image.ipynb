# %%
import nibabel as nb
import os
import matplotlib.pyplot as plt
import numpy as np
import pylab
import matplotlib.cm as cm
import skimage

# %%
# ids = os.listdir("C:\Projects\Sarvagya_work\segmentation\data\segmentation_project")
# ids = ids[6:]
# ids.remove("sub-9043")
# print(ids)

# %%
# for sub_id in ids:

#     print(sub_id)
#     files = os.listdir('C:/Projects/Sarvagya_work/segmentation/data/segmentation_project/'+sub_id+'/ses-TBSLmrSP/lumbar_megre3d')
#     files[-1]
#     labels_img = os.listdir("c:/Projects/Sarvagya_work/segmentation/data/segmentation_project/"+sub_id+"/ses-TBSLmrSP/lumbar_megre3d/derivatives/label/")
#     print(labels_img[-1])
#     img = nb.load('C:/Projects/Sarvagya_work/segmentation/data/segmentation_project/'+sub_id+'/ses-TBSLmrSP/lumbar_megre3d/'+files[-1])
#     img_data = img.get_fdata()

#     newpath_original = "c:/Projects/Sarvagya_work/segmentation/data/segmentation_project/med2image/"+sub_id+"/original/"
#     newpath_segmented = "c:/Projects/Sarvagya_work/segmentation/data/segmentation_project/med2image/"+sub_id+"/segmented_images/"
#     if not os.path.exists(newpath_original):
#         os.makedirs(newpath_original)
#     if not os.path.exists(newpath_segmented):
#         os.makedirs(newpath_segmented)
#     for i in range(img_data.shape[2]):
#         x = img_data[:,:,i]
#         x = np.rot90(x,k=1)
#         pylab.imsave("c:/Projects/Sarvagya_work/segmentation/data/segmentation_project/med2image/"+sub_id+"/original/output-slice00"+str(i)+".jpg", x, cmap='gray')

#     img_labels = nb.load("c:/Projects/Sarvagya_work/segmentation/data/segmentation_project/"+sub_id+"/ses-TBSLmrSP/lumbar_megre3d/derivatives/label/"+labels_img[-1])
#     img_data_labels = img_labels.get_fdata()
#     for i in range(img_data_labels.shape[2]):
#         x = img_data_labels[:,:,i]
#         x = np.rot90(x,k=1)
#         pylab.imsave("c:/Projects/Sarvagya_work/segmentation/data/segmentation_project/med2image/"+sub_id+"/segmented_images/output-slice00"+str(i)+".jpg", x, cmap='gray')

# %%
# file = "/home/neuroimaging/Desktop/Sarvagya_work/Harmonization/MPM/BSL-002/ses-02/Results/wp1_sub_BSL-002_ses-02_map_MTsat_masked_thresh.nii"
# file = "/home/neuroimaging/Desktop/Sarvagya_work/Harmonization/MPM/BSL-002/ses-01/Results/wp1_sub_BSL-002_ses-01_map_MTsat_masked_thresh.nii"
# file = "/home/neuroimaging/Desktop/Sarvagya_work/Harmonization/MPM/BSL-002/ses-03/Results/wp1_sub_BSL-002_ses-03_map_MTsat_masked_thresh.nii"
# file = "/home/neuroimaging/Desktop/Sarvagya_work/Harmonization/MPM/NTL-008/ses-01/Results/wp1_sub_NTL-008_ses-01_map_MTsat_masked_thresh.nii"
# file = "/home/neuroimaging/Desktop/Sarvagya_work/Harmonization/MPM/NTL-008/ses-02/Results/wp1_sub_NTL-008_ses-02_map_MTsat_masked_thresh.nii"
# file = "/home/neuroimaging/Desktop/Sarvagya_work/Harmonization/MPM/NTL-008/ses-03/Results/wp1_sub_NTL-008_ses-03_map_MTsat_masked_thresh.nii"
# file = "/home/neuroimaging/Desktop/Sarvagya_work/Harmonization/MPM/ZRH-004/ses-02/Results/wp1_sub_ZRH-004_ses-02_map_MTsat_masked_thresh.nii"
file = "/home/neuroimaging/Desktop/Sarvagya_work/GM_mask/sub-80/ses-01/anat/sub-80_ses-01_acq-lumbarMEGRE3D_desc-crop_T2starw.nii"
img = nb.load(file)
img_data = img.get_fdata()

# %%
img_data.shape
x_gray = img_data[:,:,14]
x_gray = np.rot90(x_gray)
normalized_x_gray = (x_gray-np.min(x_gray))/(np.max(x_gray)-np.min(x_gray))
plt.imshow(x_gray)
plt.show()

# %%
print(img_data.shape)
ax_slices = img_data.shape[2]
# Out:
# (123, 155, 166)

# %%
plt.imshow(np.rot90(img_data[:,:,90],k=1))
plt.show()

# %%
save_folder = "/home/neuroimaging/Desktop/Sarvagya_work/Harmonization/images/ZRH-004/ses-02/axial"
os.makedirs(save_folder)
for i in range(ax_slices):
    test_image = skimage.color.gray2rgb(np.rot90(img_data[:,:,i],k=1))
    print(test_image.shape)
    plt.imsave(save_folder+"/img_"+str(f"{i:03}")+".png", test_image)
# Out:
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# (155, 123, 3)
# ...

# %%
plt.imshow(test_image)
plt.show()

# %%
axial_data = np.zeros((ax_slices, img_data[:,:,90].flatten().shape[0]))
print(img_data[:,:,90].shape)
# Out:
# (123, 155)

# %%
for i in range(ax_slices):
    print(f"{i:03}")
    # axial_data[i] = img_data[:,:,i].flatten()
# Out:
# 000
# 001
# 002
# 003
# 004
# 005
# 006
# 007
# 008
# 009
# 010
# 011
# 012
# 013
# 014
# 015
# 016
# 017
# 018
# 019
# 020
# 021
# 022
# 023
# 024
# 025
# 026
# 027
# 028
# 029
# 030
# 031
# 032
# 033
# 034
# 035
# 036
# 037
# 038
# 039
# 040
# 041
# 042
# 043
# 044
# 045
# 046
# 047
# 048
# 049
# 050
# 051
# 052
# 053
# 054
# 055
# 056
# 057
# 058
# 059
# 060
# 061
# 062
# 063
# 064
# 065
# 066
# 067
# 068
# 069
# 070
# 071
# 072
# 073
# 074
# 075
# 076
# 077
# 078
# 079
# 080
# 081
# 082
# 083
# 084
# 085
# 086
# 087
# 088
# 089
# 090
# 091
# 092
# 093
# 094
# 095
# 096
# 097
# 098
# 099
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165

# %%
axial_data[90]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
plt.plot(axial_data[:, 10000])
